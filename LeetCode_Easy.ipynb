# %% [markdown]
# <a href="https://colab.research.google.com/github/Leeyeji13/LeetCode/blob/main/LeetCode_Easy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. Two Sum

# %% [markdown]
# 주어진 배열에 있는 두 원소를 더해 target 값을 만들 수 있을 때 그 두 원소의 index를 반환하는 알고리즘

# %% [markdown]
# ## 방법 1

# %%
class Solution(object):
    def twoSum(self, nums, target):
        """
        :type nums: List[int]
        :type target: int
        :rtype: List[int]
        """
        for i in range(len(nums)):
                for j in range(i + 1, len(nums)):
                        if nums[i] + nums[j] == target:
                                return [i, j]

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 방법 2

# %%
class Solution(object):
    def twoSum(self, nums, target):
        """
        :type nums: List[int]
        :type target: int
        :rtype: List[int]
        """
        nums_dict = {num: ind for ind, num in enumerate(nums)}
        for ind, num in enumerate(nums):
                if ((target - num) in nums_dict) and (ind != nums_dict[(target - num)]):
                        return [ind, nums_dict[(target - num)]]

# %% [markdown]
# ![image.png](data:image/png;base64,...)
